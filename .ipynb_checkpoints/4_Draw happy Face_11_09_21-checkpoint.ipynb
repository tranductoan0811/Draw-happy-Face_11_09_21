# %%
import turtle
#define background color
turtle.bgcolor("#C2D4E6")
#define pencolor
turtle.pencolor("#5D7790")
#for ouside circle
facesize = 200
turtle.penup()
turtle.goto(0,-200)
turtle.pendown()
#define pensize
turtle.pensize(6)
turtle.circle(facesize)
#for eyes
turtle.fillcolor("#8BBAE8")
turtle.penup()
turtle.goto(-100,50)
turtle.pendown()
turtle.pensize(3)
# khai báo biến eyes size
eye_size = 17.5
turtle.begin_fill()
turtle.circle(eye_size)
turtle.end_fill()

turtle.penup()
turtle.goto(100,50)
turtle.pendown()
turtle.begin_fill()
turtle.circle(eye_size)
turtle.end_fill()

#for nose (vẽ mũi)
turtle.penup()
turtle.goto(0,50)
turtle.pendown()
turtle.begin_fill()
turtle.circle(-70,steps=3)
turtle.end_fill()


#draw half of mouth
turtle.penup()
turtle.goto(-90,-80)
turtle.pendown()
turtle.pensize(8)
turtle.right(60)
turtle.circle(100,118)
turtle.mainloop()

# %%
import turtle
pen=turtle.Turtle()
turtle.bgcolor("#CCD9E7")
#Vẽ mặt ngoài
pen.penup()
pen.goto(0,-200)
pen.pendown()
pen.pensize(5)
pen.pencolor("#82A4C8")
pen.circle(200)
#Vẽ mặt cười
pen.penup()
pen.goto(-100,-70)
pen.down()
pen.pencolor("#78A55F")
pen.pensize(4)
pen.rt(50)
pen.circle(80,130)
pen.fillcolor("white")
pen.penup()
pen.home()
pen.goto(0,-70)
pen.goto(15,-70)
pen.pendown()
pen.begin_fill()
pen.pencolor("black")
pen.pensize(1)
pen.rt(90)
pen.fd(25)
pen.rt(90)
pen.fd(30)
pen.rt(90)
pen.fd(25)
pen.end_fill()
pen.fillcolor("white")
pen.penup()
pen.goto(0,-70)
pen.pendown()
pen.begin_fill()
pen.rt(20)
pen.fd(25)
pen.end_fill()
turtle.done
# Out:
# <function turtle.mainloop()>

# %%
import turtle
pen = turtle.Turtle()
turtle.bgcolor("#E2F3D9")
pen.fillcolor("#68974F")
pen.penup()
pen.goto(-100,0)
pen.pendown()
pen.pensize(2)
pen.pencolor("#99B7CB")
pen.rt(20)
pen.circle(200,45)
pen.penup()
pen.goto(-100,0)
pen.pendown()
pen.pensize(4)
pen.pencolor("#99B7CB")
pen.lt(45)
pen.circle(230,45)

# %%
import turtle
pen = turtle.Turtle()
turtle.bgcolor("#E2F3D9")
pen.fillcolor("#68974F")
pen.penup()
pen.goto(-100,0)
pen.pendown()
pen.pensize(2)
pen.pencolor("#99B7CB")
pen.rt(20)
pen.circle(200,360)
